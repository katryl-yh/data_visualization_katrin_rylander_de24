# %% [markdown]
# # 2. Gapminder dashboard
#
# Use the gapminder dataset from plotly.express and create a dashboard.
# Do explorative data analysis, pick out graphs and metrics you are interested in displaying

# %%
import plotly.express as px

gapminder = px.data.gapminder()
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
# Filter by year (for example, 1972)
year_filter = 1972
df_filtered = gapminder[gapminder['year'] == year_filter]

# %%
# Group by continent, sum population, and average life expectancy
result = df_filtered.groupby('continent').agg({
    'pop': 'sum',          # total population per continent
    'lifeExp': 'mean',      # average life expectancy per continent
    'gdpPercap' : 'mean'
}).reset_index()

result
# Out:
#   continent         pop    lifeExp     gdpPercap
# 0    Africa   379879541  47.450942   2339.615674
# 1  Americas   529384210  62.394920   6491.334139
# 2      Asia  2150972248  57.319269   8187.468699
# 3    Europe   500635059  70.775033  12479.575246
# 4   Oceania    16106100  71.910000  16417.333380

# %%
# group over multiple years at once
result_y_range = gapminder.groupby(['year', 'continent']).agg({
    'pop': 'sum',
    'lifeExp': 'mean'
}).reset_index()

result_y_range
# Out:
#     year continent         pop    lifeExp
# 0   1952    Africa   237640501  39.135500
# 1   1952  Americas   345152446  53.279840
# 2   1952      Asia  1395357351  46.314394
# 3   1952    Europe   418120846  64.408500
# 4   1952   Oceania    10686006  69.255000
# 5   1957    Africa   264837738  41.266346
# 6   1957  Americas   386953916  55.960280
# 7   1957      Asia  1562780599  49.318544
# 8   1957    Europe   437890351  66.703067
# 9   1957   Oceania    11941976  70.295000
# 10  1962    Africa   296516865  43.319442
# 11  1962  Americas   433270254  58.398760
# 12  1962      Asia  1696357182  51.563223
# 13  1962    Europe   460355155  68.539233
# 14  1962   Oceania    13283518  71.085000
# 15  1967    Africa   335289489  45.334538
# 16  1967  Americas   480746623  60.410920
# 17  1967      Asia  1905662900  54.663640
# 18  1967    Europe   481178958  69.737600
# 19  1967   Oceania    14600414  71.310000
# 20  1972    Africa   379879541  47.450942
# ...
